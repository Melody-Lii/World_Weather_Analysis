# %% [markdown]
# # Challenge Part 1 Get the weather description and amount of precipitation for each city

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
# Import the requests library.
import requests

from datetime import datetime
 
# Import the API key.
from config import weather_api_key

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("-" * 25)

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
  
  # Add 1 to the record count.
    record_count += 1
    
    try: 
        city_weather = requests.get(city_url).json()
        # print(city_url)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try: 
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data
        city_data.append(
        {
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Current Description": city_weather_description,
            "Rain (inches)": city_rain_inches,
            "Snow (inches)": city_snow_inches,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country
        })
    except: 
        print("City not found. Skipping...")
        pass
        
 # Indicate that Data Loading is complete.
print("-" * 20)
print("Data Retrieval Complete")
print("-" * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | san quintin
# Processing Record 4 of Set 1 | quelimane
# Processing Record 5 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | saint-augustin
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | aksu
# Processing Record 12 of Set 1 | naze
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | hamilton
# Processing Record 15 of Set 1 | maldonado
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | pochutla
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | tarbagatay
# Processing Record 23 of Set 1 | krasnoselkup
# Processing Record 24 of Set 1 | parangan
# Processing Record 25 of Set 1 | dourbali
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 1 | fairview
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | vila velha
# Processing Record 33 of Set 1 | nosy varika
# Processing Record 34 of Set 1 | port-de-paix
# City not found. Skipping...
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | zhigansk
# Processing Record 39 of Set 1 | siocon
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | beringovskiy
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | south venice
# Processing Record 44 of Set 1 | cozumel
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | half moon bay
# Processing Record 49 of Set 1 | kenai
# Processing Record 50 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 2 | gazanjyk
# Processing Record 2 of Set 2 | cayenne
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | wattegama
# Processing Record 8 of Set 2 | tabory
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | kandrian
# Processing Record 12 of Set 2 | kahului
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | takoradi
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | sobolevo
# Processing Record 17 of Set 2 | primorsko
# Processing Record 18 of Set 2 | teknaf
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | basco
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | bata
# Processing Record 26 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 2 | guerrero negro
# Processing Record 28 of Set 2 | itarema
# Processing Record 29 of Set 2 | hami
# Processing Record 30 of Set 2 | khani
# Processing Record 31 of Set 2 | gimbi
# Processing Record 32 of Set 2 | prince rupert
# Processing Record 33 of Set 2 | dangriga
# Processing Record 34 of Set 2 | deputatskiy
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | lavrentiya
# Processing Record 37 of Set 2 | tuatapere
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | coihaique
# Processing Record 40 of Set 2 | victor harbor
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | tillabery
# City not found. Skipping...
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | tandil
# Processing Record 47 of Set 2 | niquero
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | baykit
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | thaton
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 3 | antofagasta
# Processing Record 7 of Set 3 | vuktyl
# Processing Record 8 of Set 3 | dagana
# Processing Record 9 of Set 3 | hvide sande
# Processing Record 10 of Set 3 | tura
# Processing Record 11 of Set 3 | sao filipe
# Processing Record 12 of Set 3 | barrow
# Processing Record 13 of Set 3 | hasaki
# Processing Record 14 of Set 3 | carmo do paranaiba
# Processing Record 15 of Set 3 | elat
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | kamenka
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | new gloucester
# Processing Record 21 of Set 3 | nanortalik
# Processing Record 22 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | nyurba
# Processing Record 25 of Set 3 | kavaratti
# Processing Record 26 of Set 3 | abalak
# Processing Record 27 of Set 3 | vestmannaeyjar
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | la ronge
# Processing Record 30 of Set 3 | kodinsk
# Processing Record 31 of Set 3 | bonthe
# Processing Record 32 of Set 3 | ahipara
# Processing Record 33 of Set 3 | tanete
# Processing Record 34 of Set 3 | riyadh
# Processing Record 35 of Set 3 | jalu
# Processing Record 36 of Set 3 | qasigiannguit
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | mugla
# Processing Record 39 of Set 3 | chiang rai
# Processing Record 40 of Set 3 | girona
# Processing Record 41 of Set 3 | tomatlan
# Processing Record 42 of Set 3 | road town
# Processing Record 43 of Set 3 | labuhan
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | general roca
# Processing Record 46 of Set 3 | san cristobal
# Processing Record 47 of Set 3 | vaini
# Processing Record 48 of Set 3 | taoudenni
# Processing Record 49 of Set 3 | panalingaan
# Processing Record 50 of Set 3 | orcopampa
# Processing Record 1 of Set 4 | gorontalo
# Processing Record 2 of Set 4 | ixtapa
# Processing Record 3 of Set 4 | talnakh
# Processing Record 4 of Set 4 | kastrakion
# Processing Record 5 of Set 4 | cap malheureux
# Processing Record 6 of Set 4 | oksfjord
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | ullapool
# Processing Record 10 of Set 4 | mar del plata
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | pacifica
# Processing Record 13 of Set 4 | umtata
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | linguere
# Processing Record 16 of Set 4 | honningsvag
# Processing Record 17 of Set 4 | winnemucca
# Processing Record 18 of Set 4 | san patricio
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | qiryat gat
# Processing Record 21 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 4 | banda aceh
# Processing Record 23 of Set 4 | lazaro cardenas
# Processing Record 24 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 4 | hambantota
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | radeberg
# Processing Record 28 of Set 4 | makasar
# Processing Record 29 of Set 4 | rundu
# Processing Record 30 of Set 4 | harlingen
# Processing Record 31 of Set 4 | jining
# Processing Record 32 of Set 4 | sao joao da barra
# Processing Record 33 of Set 4 | guapore
# Processing Record 34 of Set 4 | puerto maldonado
# Processing Record 35 of Set 4 | pangkalanbuun
# Processing Record 36 of Set 4 | jalalabad
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | buin
# Processing Record 40 of Set 4 | banjarmasin
# Processing Record 41 of Set 4 | kupang
# Processing Record 42 of Set 4 | atambua
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | gunjur
# Processing Record 46 of Set 4 | los llanos de aridane
# Processing Record 47 of Set 4 | coquimbo
# Processing Record 48 of Set 4 | severo-kurilsk
# Processing Record 49 of Set 4 | areni
# Processing Record 50 of Set 4 | lorengau
# Processing Record 1 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 5 | rosita
# Processing Record 3 of Set 5 | nara
# Processing Record 4 of Set 5 | clyde
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | jumla
# Processing Record 8 of Set 5 | tucuma
# Processing Record 9 of Set 5 | tilichiki
# Processing Record 10 of Set 5 | shenkursk
# Processing Record 11 of Set 5 | kondinskoye
# Processing Record 12 of Set 5 | grindavik
# Processing Record 13 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 5 | kinwat
# Processing Record 15 of Set 5 | arica
# Processing Record 16 of Set 5 | erlenbach
# Processing Record 17 of Set 5 | puli
# Processing Record 18 of Set 5 | wisconsin rapids
# Processing Record 19 of Set 5 | xichang
# Processing Record 20 of Set 5 | bilma
# Processing Record 21 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 22 of Set 5 | cuamba
# Processing Record 23 of Set 5 | teya
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | alta floresta
# Processing Record 26 of Set 5 | bryan
# Processing Record 27 of Set 5 | buala
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | norman wells
# Processing Record 30 of Set 5 | katsuura
# Processing Record 31 of Set 5 | tigil
# Processing Record 32 of Set 5 | ladushkin
# Processing Record 33 of Set 5 | qandala
# Processing Record 34 of Set 5 | sao lourenco do sul
# Processing Record 35 of Set 5 | bairiki
# Processing Record 36 of Set 5 | klaksvik
# Processing Record 37 of Set 5 | airai
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 5 | nantucket
# Processing Record 41 of Set 5 | ostrovnoy
# Processing Record 42 of Set 5 | chicama
# Processing Record 43 of Set 5 | port hedland
# Processing Record 44 of Set 5 | nouadhibou
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | havre-saint-pierre
# Processing Record 47 of Set 5 | asau
# Processing Record 48 of Set 5 | rivera
# Processing Record 49 of Set 5 | wajima
# Processing Record 50 of Set 5 | yar-sale
# Processing Record 1 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 6 | geraldton
# Processing Record 3 of Set 6 | vila franca do campo
# Processing Record 4 of Set 6 | san juan de los morros
# Processing Record 5 of Set 6 | te anau
# Processing Record 6 of Set 6 | tombouctou
# Processing Record 7 of Set 6 | dikson
# Processing Record 8 of Set 6 | khatanga
# Processing Record 9 of Set 6 | obigarm
# Processing Record 10 of Set 6 | aripuana
# Processing Record 11 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 6 | inuvik
# Processing Record 13 of Set 6 | deep river
# Processing Record 14 of Set 6 | ponto novo
# Processing Record 15 of Set 6 | furukawa
# Processing Record 16 of Set 6 | mitu
# Processing Record 17 of Set 6 | lagoa
# Processing Record 18 of Set 6 | depalpur
# Processing Record 19 of Set 6 | apple valley
# Processing Record 20 of Set 6 | east london
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 6 | bajil
# Processing Record 24 of Set 6 | noumea
# Processing Record 25 of Set 6 | robertsport
# Processing Record 26 of Set 6 | dire
# Processing Record 27 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 6 | felipe carrillo puerto
# Processing Record 29 of Set 6 | north bend
# Processing Record 30 of Set 6 | yashkul
# Processing Record 31 of Set 6 | vao
# Processing Record 32 of Set 6 | san jeronimito
# Processing Record 33 of Set 6 | sampit
# Processing Record 34 of Set 6 | port blair
# Processing Record 35 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 6 | roebourne
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | vanimo
# Processing Record 39 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 6 | san policarpo
# Processing Record 41 of Set 6 | havoysund
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | the pas
# Processing Record 44 of Set 6 | kyzyl-suu
# Processing Record 45 of Set 6 | victoria
# Processing Record 46 of Set 6 | hualmay
# Processing Record 47 of Set 6 | suihua
# Processing Record 48 of Set 6 | sur
# Processing Record 49 of Set 6 | marfino
# Processing Record 50 of Set 6 | lasa
# Processing Record 1 of Set 7 | hobyo
# Processing Record 2 of Set 7 | itaueira
# Processing Record 3 of Set 7 | parsabad
# Processing Record 4 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 7 | dunedin
# Processing Record 6 of Set 7 | asilah
# Processing Record 7 of Set 7 | sioux lookout
# Processing Record 8 of Set 7 | saint anthony
# Processing Record 9 of Set 7 | burica
# City not found. Skipping...
# Processing Record 10 of Set 7 | batsfjord
# Processing Record 11 of Set 7 | vostok
# Processing Record 12 of Set 7 | ostashkov
# Processing Record 13 of Set 7 | tecoanapa
# Processing Record 14 of Set 7 | nabire
# Processing Record 15 of Set 7 | pemangkat
# Processing Record 16 of Set 7 | sargodha
# Processing Record 17 of Set 7 | clinton
# Processing Record 18 of Set 7 | tocopilla
# Processing Record 19 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 7 | alyangula
# Processing Record 21 of Set 7 | kudahuvadhoo
# Processing Record 22 of Set 7 | koboko
# Processing Record 23 of Set 7 | ornes
# Processing Record 24 of Set 7 | vrangel
# Processing Record 25 of Set 7 | saint-georges
# Processing Record 26 of Set 7 | invermere
# Processing Record 27 of Set 7 | talcahuano
# Processing Record 28 of Set 7 | banjar
# Processing Record 29 of Set 7 | shitanjing
# Processing Record 30 of Set 7 | monroe
# Processing Record 31 of Set 7 | moron
# Processing Record 32 of Set 7 | ribeira grande
# Processing Record 33 of Set 7 | toucheng
# Processing Record 34 of Set 7 | libin
# Processing Record 35 of Set 7 | acarau
# Processing Record 36 of Set 7 | kirakira
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | tiarei
# Processing Record 39 of Set 7 | surt
# Processing Record 40 of Set 7 | tautira
# Processing Record 41 of Set 7 | monte alegre
# Processing Record 42 of Set 7 | bathsheba
# Processing Record 43 of Set 7 | coro
# Processing Record 44 of Set 7 | trat
# Processing Record 45 of Set 7 | provideniya
# Processing Record 46 of Set 7 | khandbari
# Processing Record 47 of Set 7 | berlevag
# Processing Record 48 of Set 7 | sao jose da coroa grande
# Processing Record 49 of Set 7 | saint-pierre
# Processing Record 50 of Set 7 | forset
# City not found. Skipping...
# Processing Record 1 of Set 8 | taungdwingyi
# Processing Record 2 of Set 8 | trinidad
# Processing Record 3 of Set 8 | souillac
# Processing Record 4 of Set 8 | kindu
# Processing Record 5 of Set 8 | uige
# Processing Record 6 of Set 8 | payakumbuh
# Processing Record 7 of Set 8 | sorong
# Processing Record 8 of Set 8 | mahajanga
# Processing Record 9 of Set 8 | sept-iles
# Processing Record 10 of Set 8 | milos
# Processing Record 11 of Set 8 | krasnoarmeysk
# Processing Record 12 of Set 8 | black diamond
# Processing Record 13 of Set 8 | ola
# Processing Record 14 of Set 8 | la asuncion
# Processing Record 15 of Set 8 | meulaboh
# Processing Record 16 of Set 8 | tuy hoa
# Processing Record 17 of Set 8 | belaya gora
# Processing Record 18 of Set 8 | saint-philippe
# Processing Record 19 of Set 8 | kelvington
# Processing Record 20 of Set 8 | pevek
# Processing Record 21 of Set 8 | maltahohe
# Processing Record 22 of Set 8 | manzhouli
# Processing Record 23 of Set 8 | karratha
# Processing Record 24 of Set 8 | nuuk
# Processing Record 25 of Set 8 | maiduguri
# Processing Record 26 of Set 8 | tecpan
# Processing Record 27 of Set 8 | mandalay
# Processing Record 28 of Set 8 | cape canaveral
# Processing Record 29 of Set 8 | makkaveyevo
# Processing Record 30 of Set 8 | luderitz
# Processing Record 31 of Set 8 | high prairie
# Processing Record 32 of Set 8 | merauke
# Processing Record 33 of Set 8 | grande prairie
# Processing Record 34 of Set 8 | verkhnevilyuysk
# Processing Record 35 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 8 | broken hill
# Processing Record 37 of Set 8 | acapulco
# Processing Record 38 of Set 8 | waddan
# Processing Record 39 of Set 8 | qaqortoq
# Processing Record 40 of Set 8 | kurchum
# Processing Record 41 of Set 8 | pangnirtung
# Processing Record 42 of Set 8 | zyryanka
# Processing Record 43 of Set 8 | yamada
# Processing Record 44 of Set 8 | nishihara
# Processing Record 45 of Set 8 | hukuntsi
# Processing Record 46 of Set 8 | staryy nadym
# Processing Record 47 of Set 8 | lompoc
# Processing Record 48 of Set 8 | morondava
# Processing Record 49 of Set 8 | berdigestyakh
# Processing Record 50 of Set 8 | dalaba
# Processing Record 1 of Set 9 | padang
# Processing Record 2 of Set 9 | dicabisagan
# Processing Record 3 of Set 9 | saint george
# Processing Record 4 of Set 9 | karasburg
# Processing Record 5 of Set 9 | nha trang
# Processing Record 6 of Set 9 | gimli
# Processing Record 7 of Set 9 | suicheng
# Processing Record 8 of Set 9 | topolobampo
# Processing Record 9 of Set 9 | fort nelson
# Processing Record 10 of Set 9 | smidovich
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | syracuse
# Processing Record 13 of Set 9 | rosetta
# Processing Record 14 of Set 9 | posadas
# Processing Record 15 of Set 9 | pavlogradka
# Processing Record 16 of Set 9 | mayumba
# Processing Record 17 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 19 of Set 9 | qostanay
# Processing Record 20 of Set 9 | aykhal
# Processing Record 21 of Set 9 | porto novo
# Processing Record 22 of Set 9 | ingleside
# Processing Record 23 of Set 9 | valley city
# Processing Record 24 of Set 9 | kathu
# Processing Record 25 of Set 9 | nardaran
# Processing Record 26 of Set 9 | high level
# Processing Record 27 of Set 9 | port-gentil
# Processing Record 28 of Set 9 | yulara
# Processing Record 29 of Set 9 | tim
# Processing Record 30 of Set 9 | najran
# Processing Record 31 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 9 | warrnambool
# Processing Record 33 of Set 9 | manoel urbano
# Processing Record 34 of Set 9 | kattivakkam
# Processing Record 35 of Set 9 | marawi
# Processing Record 36 of Set 9 | coahuayana
# Processing Record 37 of Set 9 | viet tri
# Processing Record 38 of Set 9 | caibarien
# Processing Record 39 of Set 9 | tananger
# Processing Record 40 of Set 9 | shenjiamen
# Processing Record 41 of Set 9 | lata
# Processing Record 42 of Set 9 | samarai
# Processing Record 43 of Set 9 | laguna
# Processing Record 44 of Set 9 | emerald
# Processing Record 45 of Set 9 | waipawa
# Processing Record 46 of Set 9 | coos bay
# Processing Record 47 of Set 9 | tabou
# Processing Record 48 of Set 9 | uji
# Processing Record 49 of Set 9 | port hardy
# Processing Record 50 of Set 9 | sarai naurang
# Processing Record 1 of Set 10 | torrington
# Processing Record 2 of Set 10 | monrovia
# Processing Record 3 of Set 10 | sulangan
# Processing Record 4 of Set 10 | saint pete beach
# Processing Record 5 of Set 10 | anadyr
# Processing Record 6 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 10 | sterling
# Processing Record 8 of Set 10 | peterhead
# Processing Record 9 of Set 10 | umm lajj
# Processing Record 10 of Set 10 | hanzhong
# Processing Record 11 of Set 10 | riverton
# Processing Record 12 of Set 10 | namibe
# Processing Record 13 of Set 10 | whitehorse
# Processing Record 14 of Set 10 | comodoro rivadavia
# Processing Record 15 of Set 10 | alghero
# Processing Record 16 of Set 10 | albury
# Processing Record 17 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 10 | aklavik
# Processing Record 19 of Set 10 | huarmey
# Processing Record 20 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 21 of Set 10 | kaupanger
# Processing Record 22 of Set 10 | amanganj
# Processing Record 23 of Set 10 | guaratinga
# Processing Record 24 of Set 10 | burgersdorp
# Processing Record 25 of Set 10 | sergiyevsk
# Processing Record 26 of Set 10 | singaraja
# Processing Record 27 of Set 10 | palmares do sul
# Processing Record 28 of Set 10 | dubai
# Processing Record 29 of Set 10 | srednekolymsk
# Processing Record 30 of Set 10 | marataizes
# Processing Record 31 of Set 10 | ramgarh
# Processing Record 32 of Set 10 | port keats
# Processing Record 33 of Set 10 | westport
# Processing Record 34 of Set 10 | san luis
# Processing Record 35 of Set 10 | kilifi
# Processing Record 36 of Set 10 | nome
# Processing Record 37 of Set 10 | maniitsoq
# Processing Record 38 of Set 10 | kainantu
# Processing Record 39 of Set 10 | birao
# Processing Record 40 of Set 10 | kargasok
# Processing Record 41 of Set 10 | sioux falls
# Processing Record 42 of Set 10 | mehran
# Processing Record 43 of Set 10 | akureyri
# Processing Record 44 of Set 10 | linqiong
# Processing Record 45 of Set 10 | moose factory
# Processing Record 46 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 10 | northam
# Processing Record 48 of Set 10 | chapada dos guimaraes
# Processing Record 49 of Set 10 | gigmoto
# Processing Record 50 of Set 10 | hargeysa
# Processing Record 1 of Set 11 | shache
# Processing Record 2 of Set 11 | santa isabel do rio negro
# Processing Record 3 of Set 11 | beloha
# Processing Record 4 of Set 11 | abha
# Processing Record 5 of Set 11 | mpanda
# Processing Record 6 of Set 11 | nemuro
# Processing Record 7 of Set 11 | taitung
# Processing Record 8 of Set 11 | komsomolskiy
# Processing Record 9 of Set 11 | verkhnyaya inta
# Processing Record 10 of Set 11 | yunhe
# Processing Record 11 of Set 11 | serrinha
# Processing Record 12 of Set 11 | manjacaze
# Processing Record 13 of Set 11 | aquiraz
# Processing Record 14 of Set 11 | talara
# Processing Record 15 of Set 11 | waitati
# Processing Record 16 of Set 11 | poronaysk
# Processing Record 17 of Set 11 | gamba
# Processing Record 18 of Set 11 | ilhabela
# Processing Record 19 of Set 11 | sabzevar
# Processing Record 20 of Set 11 | ust-nera
# Processing Record 21 of Set 11 | sudova vyshnya
# Processing Record 22 of Set 11 | wanning
# Processing Record 23 of Set 11 | ottappalam
# Processing Record 24 of Set 11 | hearst
# Processing Record 25 of Set 11 | newala
# Processing Record 26 of Set 11 | berlin
# Processing Record 27 of Set 11 | aojiang
# Processing Record 28 of Set 11 | praia da vitoria
# Processing Record 29 of Set 11 | salym
# Processing Record 30 of Set 11 | mildura
# Processing Record 31 of Set 11 | paragominas
# Processing Record 32 of Set 11 | jati
# Processing Record 33 of Set 11 | petauke
# Processing Record 34 of Set 11 | haines junction
# Processing Record 35 of Set 11 | tommot
# Processing Record 36 of Set 11 | gondanglegi
# Processing Record 37 of Set 11 | san angelo
# Processing Record 38 of Set 11 | songea
# Processing Record 39 of Set 11 | flin flon
# Processing Record 40 of Set 11 | mukhen
# Processing Record 41 of Set 11 | pouebo
# Processing Record 42 of Set 11 | seoul
# Processing Record 43 of Set 11 | tarui
# Processing Record 44 of Set 11 | birjand
# Processing Record 45 of Set 11 | phuket
# Processing Record 46 of Set 11 | kaya
# Processing Record 47 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 48 of Set 11 | caravelas
# Processing Record 49 of Set 11 | mbandaka
# Processing Record 50 of Set 11 | ilulissat
# Processing Record 1 of Set 12 | morros
# Processing Record 2 of Set 12 | sembe
# Processing Record 3 of Set 12 | saint-francois
# Processing Record 4 of Set 12 | jacareacanga
# Processing Record 5 of Set 12 | ekibastuz
# Processing Record 6 of Set 12 | bitung
# Processing Record 7 of Set 12 | manadhoo
# Processing Record 8 of Set 12 | minas
# Processing Record 9 of Set 12 | presque isle
# Processing Record 10 of Set 12 | suzhou
# Processing Record 11 of Set 12 | luanda
# Processing Record 12 of Set 12 | izumo
# Processing Record 13 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 14 of Set 12 | esperance
# Processing Record 15 of Set 12 | zhanjiang
# Processing Record 16 of Set 12 | port macquarie
# Processing Record 17 of Set 12 | santa maria del oro
# Processing Record 18 of Set 12 | basavana bagevadi
# Processing Record 19 of Set 12 | fallon
# Processing Record 20 of Set 12 | iracoubo
# Processing Record 21 of Set 12 | nortelandia
# Processing Record 22 of Set 12 | hovd
# Processing Record 23 of Set 12 | pitea
# Processing Record 24 of Set 12 | carutapera
# Processing Record 25 of Set 12 | erenhot
# Processing Record 26 of Set 12 | guiyang
# Processing Record 27 of Set 12 | valle hermoso
# Processing Record 28 of Set 12 | ugoofaaru
# Processing Record 29 of Set 12 | basarabeasca
# Processing Record 30 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 12 | touros
# Processing Record 32 of Set 12 | chara
# Processing Record 33 of Set 12 | do rud
# City not found. Skipping...
# Processing Record 34 of Set 12 | manicore
# Processing Record 35 of Set 12 | ipixuna
# Processing Record 36 of Set 12 | burns lake
# Processing Record 37 of Set 12 | santa barbara
# Processing Record 38 of Set 12 | ranau
# Processing Record 39 of Set 12 | palmer
# Processing Record 40 of Set 12 | codrington
# Processing Record 41 of Set 12 | canchungo
# Processing Record 42 of Set 12 | lakatoro
# Processing Record 43 of Set 12 | sena madureira
# Processing Record 44 of Set 12 | ternate
# Processing Record 45 of Set 12 | mangit
# Processing Record 46 of Set 12 | kieta
# Processing Record 47 of Set 12 | jaru
# Processing Record 48 of Set 12 | oktyabrskoye
# Processing Record 49 of Set 12 | lidkoping
# Processing Record 50 of Set 12 | auki
# Processing Record 1 of Set 13 | fortuna
# Processing Record 2 of Set 13 | baculin
# Processing Record 3 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 13 | dongsheng
# Processing Record 5 of Set 13 | minsk
# Processing Record 6 of Set 13 | ust-ilimsk
# Processing Record 7 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 13 | namatanai
# Processing Record 9 of Set 13 | eyl
# Processing Record 10 of Set 13 | kawalu
# Processing Record 11 of Set 13 | dawlatabad
# Processing Record 12 of Set 13 | kautokeino
# Processing Record 13 of Set 13 | puerto escondido
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 568

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp      Current Description  \
# 0       hithadhoo  -0.60   73.08     84.42          overcast clouds
# 1       carnarvon -24.87  113.63     71.60                clear sky
# 2     san quintin  30.48 -115.95     61.66               few clouds
# 3       quelimane -17.88   36.89     74.61               few clouds
# 4         mataura -46.19  168.86     44.83                clear sky
# 5  saint-augustin  51.23  -58.65     59.41          overcast clouds
# 6    punta arenas -53.15  -70.92     28.40            broken clouds
# 7         ushuaia -54.80  -68.30     33.80  light intensity drizzle
# 8            aksu  41.12   80.26     87.39         scattered clouds
# 9            naze  28.37  129.48     84.20            broken clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0            0.0            0.0        75         100       11.05      MV
# 1            0.0            0.0        53           0       12.75      AU
# 2            0.0            0.0        91          24        5.61      MX
# 3            0.0            0.0        67          19        8.75      MZ
# 4            0.0            0.0        81           0        8.55      NZ
# 5            0.0            0.0        94         100        9.89      CA
# 6            0.0            0.0        92          84        5.82      CL
# 7            0.0            0.0        96          90        5.82      AR
# 8            0.0            0.0        15          47        1.86      CN
# 9            0.0            0.0        89          75       16.11      JP

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = sorted(city_data_df.columns.tolist())
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City  Cloudiness Country Current Description  Humidity  \
# 0           hithadhoo         100      MV     overcast clouds        75
# 1           carnarvon           0      AU           clear sky        53
# 2         san quintin          24      MX          few clouds        91
# 3           quelimane          19      MZ          few clouds        67
# 4             mataura           0      NZ           clear sky        81
# ..                ...         ...     ...                 ...       ...
# 563               eyl           0      SO           clear sky        44
# 564            kawalu          83      ID          light rain        77
# 565        dawlatabad           0      AF           clear sky         8
# 566        kautokeino          94      NO     overcast clouds        53
# 567  puerto escondido          58      MX       broken clouds        72
#
#        Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 0    -0.60   73.08     84.42           0.00           0.00       11.05
# 1   -24.87  113.63     71.60           0.00           0.00       12.75
# 2    30.48 -115.95     61.66           0.00           0.00        5.61
# 3   -17.88   36.89     74.61           0.00           0.00        8.75
# 4   -46.19  168.86     44.83           0.00           0.00        8.55
# ..     ...     ...       ...            ...            ...         ...
# 563   7.98   49.82     91.81           0.00           0.00       28.25
# 564  -7.38  108.21     79.47           0.14           0.14        5.61
# 565  36.41   64.91    100.98           0.00           0.00        7.45
# 566  69.01   23.04     67.06           0.00           0.00       17.58
# 567  15.85  -97.07     79.81           0.00           0.00        5.17
#
# [568 rows x 11 columns]

# %%
city_data_df.dtypes
# Out:
# City                    object
# Cloudiness               int64
# Country                 object
# Current Description     object
# Humidity                 int64
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Rain (inches)          float64
# Snow (inches)          float64
# Wind Speed             float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] >0]
raining_cities.head()
# Out:
#            City  Cloudiness Country Current Description  Humidity    Lat  \
# 16  new norfolk          10      AU          light rain        81 -42.78
# 21     parangan         100      PH          light rain        70   5.08
# 23       dingle         100      PH          light rain        63  11.00
# 29  nosy varika          66      MG          light rain        78 -20.58
# 34       siocon         100      PH          light rain        76   7.71
#
#        Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 16  147.06     52.00           0.89           0.89        3.00
# 21  119.94     84.38           0.26           0.26        4.21
# 23  122.67     89.29           0.61           0.61        7.81
# 29   48.53     73.71           0.30           0.30        6.98
# 34  122.14     82.85           0.94           0.94        1.14

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] >0]
snowing_cities.head()
# Out:
#            City  Cloudiness Country Current Description  Humidity    Lat  \
# 16  new norfolk          10      AU          light rain        81 -42.78
# 21     parangan         100      PH          light rain        70   5.08
# 23       dingle         100      PH          light rain        63  11.00
# 29  nosy varika          66      MG          light rain        78 -20.58
# 34       siocon         100      PH          light rain        76   7.71
#
#        Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 16  147.06     52.00           0.89           0.89        3.00
# 21  119.94     84.38           0.26           0.26        4.21
# 23  122.67     89.29           0.61           0.61        7.81
# 29   48.53     73.71           0.30           0.30        6.98
# 34  122.14     82.85           0.94           0.94        1.14

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
