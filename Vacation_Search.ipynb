# %% [markdown]
# ## Challenge Part 2 Have Customers Narrow Their Travel Searches Based on Temperature and Precipitation

# %%
import pandas as pd
import requests
import gmaps

from config import g_key

# %%
city_data_df = pd.read_csv("./data/WeatherPy_Database.csv")
city_data_df
# Out:
#      City_ID              City  Cloudiness Country Current Description  \
# 0          0         hithadhoo         100      MV     overcast clouds
# 1          1         carnarvon           0      AU           clear sky
# 2          2       san quintin          24      MX          few clouds
# 3          3         quelimane          19      MZ          few clouds
# 4          4           mataura           0      NZ           clear sky
# ..       ...               ...         ...     ...                 ...
# 563      563               eyl           0      SO           clear sky
# 564      564            kawalu          83      ID          light rain
# 565      565        dawlatabad           0      AF           clear sky
# 566      566        kautokeino          94      NO     overcast clouds
# 567      567  puerto escondido          58      MX       broken clouds
#
#      Humidity    Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  \
# 0          75  -0.60   73.08     84.42           0.00           0.00
# 1          53 -24.87  113.63     71.60           0.00           0.00
# 2          91  30.48 -115.95     61.66           0.00           0.00
# 3          67 -17.88   36.89     74.61           0.00           0.00
# 4          81 -46.19  168.86     44.83           0.00           0.00
# ..        ...    ...     ...       ...            ...            ...
# 563        44   7.98   49.82     91.81           0.00           0.00
# 564        77  -7.38  108.21     79.47           0.14           0.14
# 565         8  36.41   64.91    100.98           0.00           0.00
# 566        53  69.01   23.04     67.06           0.00           0.00
# 567        72  15.85  -97.07     79.81           0.00           0.00
#
#      Wind Speed
# 0         11.05
# 1         12.75
# 2          5.61
# 3          8.75
# 4          8.55
# ..          ...
# 563       28.25
# 564        5.61
# 565        7.45
# 566       17.58
# 567        5.17
#
# [568 rows x 12 columns]

# %%
city_data_df.dtypes
# Out:
# City_ID                  int64
# City                    object
# Cloudiness               int64
# Country                 object
# Current Description     object
# Humidity                 int64
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Rain (inches)          float64
# Snow (inches)          float64
# Wind Speed             float64
# dtype: object

# %%
# configure gmaps
gmaps.configure(api_key=g_key)

# %%
# Enter max temprature critieria
min_temp = float(input("What is the minimum temperature you would like for your vacation? "))
max_temp = float(input("What is the maximum temperature you would like for your vacation? "))
# Out:
# What is the minimum temperature you would like for your vacation? 60
# What is the maximum temperature you would like for your vacation? 200

# %%
# Ask the customer if you want it to be raining
rain_amount = input("Do you want it to be raining? (yes/no)")
# Out:
# Do you want it to be raining? (yes/no)no

# %%
snow_amount = input("Do you wnat it to be snowing (yes/no)")
# Out:
# Do you wnat it to be snowing (yes/no)no

# %%
if rain_amount == "no" and snow_amount == "no":
    filtered_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) &
                                          (city_data_df["Max Temp"] >= min_temp) &
                                          (city_data_df["Rain (inches)"] == 0) &
                                          (city_data_df["Snow (inches)"] == 0)]
elif rain_amount == "no" and snow_amount == "yes":
    filtered_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) &
                                          (city_data_df["Max Temp"] >= min_temp) &
                                          (city_data_df["Rain (inches)"] == 0) &
                                          (city_data_df["Snow (inches)"] >= 0.0)]
elif rain_amount == "yes" and snow_amount == "no":
    filtered_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) &
                                          (city_data_df["Max Temp"] >= min_temp) &
                                          (city_data_df["Rain (inches)"] > 0.0) &
                                          (city_data_df["Snow (inches)"] == 0)]
else:
    filtered_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) &
                                          (city_data_df["Max Temp"] >= min_temp) &
                                          (city_data_df["Rain (inches)"] > 0.0) &
                                          (city_data_df["Snow (inches)"] > 0)]

# %%
filtered_cities_df.head()
# Out:
#    City_ID         City  Cloudiness Country Current Description  Humidity  \
# 0        0    hithadhoo         100      MV     overcast clouds        75
# 1        1    carnarvon           0      AU           clear sky        53
# 2        2  san quintin          24      MX          few clouds        91
# 3        3    quelimane          19      MZ          few clouds        67
# 8        8         aksu          47      CN    scattered clouds        15
#
#      Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 0  -0.60   73.08     84.42            0.0            0.0       11.05
# 1 -24.87  113.63     71.60            0.0            0.0       12.75
# 2  30.48 -115.95     61.66            0.0            0.0        5.61
# 3 -17.88   36.89     74.61            0.0            0.0        8.75
# 8  41.12   80.26     87.39            0.0            0.0        1.86

# %%
filtered_cities_df.count()
# Out:
# City_ID                369
# City                   369
# Cloudiness             369
# Country                367
# Current Description    369
# Humidity               369
# Lat                    369
# Lng                    369
# Max Temp               369
# Rain (inches)          369
# Snow (inches)          369
# Wind Speed             369
# dtype: int64

# %%
filtered_cities_df = filtered_cities_df.dropna()
filtered_cities_df
# Out:
#      City_ID              City  Cloudiness Country Current Description  \
# 0          0         hithadhoo         100      MV     overcast clouds
# 1          1         carnarvon           0      AU           clear sky
# 2          2       san quintin          24      MX          few clouds
# 3          3         quelimane          19      MZ          few clouds
# 8          8              aksu          47      CN    scattered clouds
# ..       ...               ...         ...     ...                 ...
# 562      562         namatanai          92      PG     overcast clouds
# 563      563               eyl           0      SO           clear sky
# 565      565        dawlatabad           0      AF           clear sky
# 566      566        kautokeino          94      NO     overcast clouds
# 567      567  puerto escondido          58      MX       broken clouds
#
#      Humidity    Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  \
# 0          75  -0.60   73.08     84.42            0.0            0.0
# 1          53 -24.87  113.63     71.60            0.0            0.0
# 2          91  30.48 -115.95     61.66            0.0            0.0
# 3          67 -17.88   36.89     74.61            0.0            0.0
# 8          15  41.12   80.26     87.39            0.0            0.0
# ..        ...    ...     ...       ...            ...            ...
# 562        74  -3.67  152.43     82.60            0.0            0.0
# 563        44   7.98   49.82     91.81            0.0            0.0
# 565         8  36.41   64.91    100.98            0.0            0.0
# 566        53  69.01   23.04     67.06            0.0            0.0
# 567        72  15.85  -97.07     79.81            0.0            0.0
#
#      Wind Speed
# 0         11.05
# 1         12.75
# 2          5.61
# 3          8.75
# 8          1.86
# ..          ...
# 562       11.21
# 563       28.25
# 565        7.45
# 566       17.58
# 567        5.17
#
# [367 rows x 12 columns]

# %%
filtered_cities_df.count()
# Out:
# City_ID                367
# City                   367
# Cloudiness             367
# Country                367
# Current Description    367
# Humidity               367
# Lat                    367
# Lng                    367
# Max Temp               367
# Rain (inches)          367
# Snow (inches)          367
# Wind Speed             367
# dtype: int64

# %%
hotel_df = filtered_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#           City Country  Max Temp    Lat     Lng Hotel Name
# 0    hithadhoo      MV     84.42  -0.60   73.08
# 1    carnarvon      AU     71.60 -24.87  113.63
# 2  san quintin      MX     61.66  30.48 -115.95
# 3    quelimane      MZ     74.61 -17.88   36.89
# 8         aksu      CN     87.39  41.12   80.26

# %%
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

  # Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except IndexError:
        print("Hotel not found... skipping...")
# Out:
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...
# Hotel not found... skipping...

# %%
hotel_df.head()
# Out:
#           City Country  Max Temp    Lat     Lng             Hotel Name
# 0    hithadhoo      MV     84.42  -0.60   73.08      Scoop Guest House
# 1    carnarvon      AU     71.60 -24.87  113.63  Hospitality Carnarvon
# 2  san quintin      MX     61.66  30.48 -115.95         Old Mill Hotel
# 3    quelimane      MZ     74.61 -17.88   36.89         Hotel Flamingo
# 8         aksu      CN     87.39  41.12   80.26   Pudong Holiday Hotel

# %%
output_data_file = "./data/WeatherPy_Vacation.csv"
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
vacation_df = pd.read_csv("./data/WeatherPy_Vacation.csv")
vacation_df
# Out:
#      City_ID              City Country  Max Temp    Lat     Lng  \
# 0          0         hithadhoo      MV     84.42  -0.60   73.08
# 1          1         carnarvon      AU     71.60 -24.87  113.63
# 2          2       san quintin      MX     61.66  30.48 -115.95
# 3          3         quelimane      MZ     74.61 -17.88   36.89
# 4          8              aksu      CN     87.39  41.12   80.26
# ..       ...               ...     ...       ...    ...     ...
# 362      562         namatanai      PG     82.60  -3.67  152.43
# 363      563               eyl      SO     91.81   7.98   49.82
# 364      565        dawlatabad      AF    100.98  36.41   64.91
# 365      566        kautokeino      NO     67.06  69.01   23.04
# 366      567  puerto escondido      MX     79.81  15.85  -97.07
#
#                                      Hotel Name
# 0                             Scoop Guest House
# 1                         Hospitality Carnarvon
# 2                                Old Mill Hotel
# 3                                Hotel Flamingo
# 4                          Pudong Holiday Hotel
# ..                                          ...
# 362                             Namatanai Hotel
# 363                                 Amiin Hotel
# 364                            WASIM ASGAR KHAN
# 365  Ailo Matki & Tourist -Kautokeino bilutleie
# 366               Aldea del Bazar Hotel and Spa
#
# [367 rows x 7 columns]

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Hotel Name</dt><dd>{Hotel Name} at {Max Temp}</dd>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]
locations = vacation_df[["Lat","Lng"]]

# %%
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
